# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Replace this with the actual path to your dataset
dataset_path = r"C:\code\hair_diseases\traning\Plantvillage"



# Create an ImageDataGenerator for data augmentation and normalization
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Define the training generator
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),  # Adjust the target size based on your dataset
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

# Define the validation generator
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Define the LSTM model
model = models.Sequential()
model.add(layers.TimeDistributed(layers.Conv2D(32, (3, 3), activation='relu'), input_shape=(None, 256, 256, 3)))
model.add(layers.TimeDistributed(layers.MaxPooling2D((2, 2))))
model.add(layers.TimeDistributed(layers.Flatten()))
model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.LSTM(128))
model.add(layers.Dense(10, activation='softmax'))  # Adjust the output size based on your dataset

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 7680 images belonging to 10 classes.
# Found 1920 images belonging to 10 classes.
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 44
#      41 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      43 # Train the model
# ---> 44 model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
# Define the training generator
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),  # Adjust the target size based on your dataset
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True  # Ensure shuffling for better training
)

# Define the validation generator
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),  # Use the same target size as training
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False  # Do not shuffle validation data
)

# Print the shape of a batch from the generator
for batch_data, batch_labels in train_generator:
    print("Input Shape:", batch_data.shape)
    print("Label Shape:", batch_labels.shape)
    break

# Define the LSTM model
model = models.Sequential()
model.add(layers.TimeDistributed(layers.Conv2D(32, (3, 3), activation='relu'), input_shape=(num_time_steps, 64, 64, 3)))
model.add(layers.TimeDistributed(layers.MaxPooling2D((2, 2))))
model.add(layers.TimeDistributed(layers.Flatten()))
model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.LSTM(128, return_sequences=False))
model.add(layers.Dense(10, activation='softmax'))  # Adjust the output size based on your dataset

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 7680 images belonging to 10 classes.
# Found 1920 images belonging to 10 classes.
# Input Shape: (32, 64, 64, 3)
# Label Shape: (32, 10)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 29
#      27 # Define the LSTM model
#      28 model = models.Sequential()
# ---> 29 model.add(layers.TimeDistributed(layers.Conv2D(32, (3, 3), activation='relu'), input_shape=(num_time_steps, 64, 64, 3)))
#      30 model.add(layers.TimeDistributed(layers.MaxPooling2D((2, 2))))
#      31 model.add(layers.TimeDistributed(layers.Flatten()))
#
# NameError: name 'num_time_steps' is not defined

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Replace this with the actual path to your dataset
dataset_path = r"C:\code\hair_diseases\traning\Plantvillage"

# Create an ImageDataGenerator for data augmentation and normalization
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Assuming you have a fixed number of time steps, e.g., 10
num_time_steps = 10

# Define the training generator
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),  # Adjust the target size based on your dataset
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True  # Ensure shuffling for better training
)

# Define the validation generator
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),  # Use the same target size as training
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False  # Do not shuffle validation data
)

# Print the shape of a batch from the generator
for batch_data, batch_labels in train_generator:
    print("Input Shape:", batch_data.shape)
    print("Label Shape:", batch_labels.shape)
    break

# Define the LSTM model
model = models.Sequential()
model.add(layers.TimeDistributed(layers.Conv2D(32, (3, 3), activation='relu'), input_shape=(num_time_steps, 64, 64, 3)))
model.add(layers.TimeDistributed(layers.MaxPooling2D((2, 2))))
model.add(layers.TimeDistributed(layers.Flatten()))
model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.LSTM(128, return_sequences=False))
model.add(layers.Dense(10, activation='softmax'))  # Adjust the output size based on your dataset

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 7680 images belonging to 10 classes.
# Found 1920 images belonging to 10 classes.
# Input Shape: (32, 64, 64, 3)
# Label Shape: (32, 10)
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 53
#      50 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      52 # Train the model
# ---> 53 model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
# ...

# %%
import cv2
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , confusion_matrix
import tensorflow as tf
from tensorflow import keras
from keras.utils import normalize , to_categorical
from keras.models import load_model
import joblib



dataset = []
label = []
image_directory = 'C:\\code\\hair_diseases\\traning\\hairdata+'
Alopecia_Areata_images= os.listdir(image_directory + 'Alopecia_Areata')


for i , image_name in enumerate(Mild_demented_images):

    image = cv2.imread(image_directory+'MildDemented/'+image_name)
    image =Image.fromarray(image , 'RGB')
    image = image.resize((128,128))
    dataset.append(np.array(image))
    label.append(0)

Moderate_demented_images= os.listdir(image_directory + 'ModerateDemented/')


for i , image_name in enumerate(Moderate_demented_images):

    image = cv2.imread(image_directory+'ModerateDemented/'+image_name)
    image =Image.fromarray(image , 'RGB')
    image =image.resize((128,128))
    dataset.append(np.array(image))
    label.append(1)

Non_demented_images= os.listdir(image_directory + 'NonDemented/')


for i , image_name in enumerate(Non_demented_images):

    image = cv2.imread(image_directory+'NonDemented/'+image_name)
    image = Image.fromarray(image ,'RGB')
    image = image.resize((128,128))
    dataset.append(np.array(image))
    label.append(2)

VeryMild_demented_images= os.listdir(image_directory + 'VeryMildDemented/')

# bool = True
for i , image_name in enumerate(VeryMild_demented_images):
    image = cv2.imread(image_directory+'VeryMildDemented/'+image_name)
  
    image =Image.fromarray(image , 'RGB')
    image =image.resize((128,128))
    
    res = np.array(image)
    dataset.append(res)

    # if(bool == True):
        
    #     shows = Image.fromarray(res)
        
    #     shows.show()

    #     bool = False
    label.append(3)
  

dataset = np.array(dataset)
label = np.array(label)

x_train , X_test , y_train , Y_test=train_test_split(dataset , label , test_size = 0.2 , random_state=1,stratify=label)

#print(X_test.shape)

x_train= normalize(x_train , axis=1)
X_test = normalize(X_test , axis=1)

#rf= joblib.load('Alzheimer_rf_model.joblib')

rf = RandomForestClassifier(criterion='gini', n_estimators=1000,random_state=1 ,n_jobs=2)
nsamples, nx, ny , c= x_train.shape
x_train = x_train.reshape((nsamples,nx*ny*c))

nsamples, nx, ny , c= X_test.shape
X_test = X_test.reshape((nsamples,nx*ny*c))

rf.fit(x_train,y_train)

y_pred = rf.predict(X_test)
accuracy = accuracy_score(Y_test,y_pred)
print(accuracy)
# for i in Y_test:
#     print(i)
# print(len(Y_test))
# for i in y_pred:
#     print(i)
# print(len(y_pred))
joblib.dump(rf, "Alzheimer_rf_model.joblib")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 20
#      17 label = []
#      18 image_directory = 'C:\\code\\hair_diseases\\traning\\hairdata+'
# ---> 20 Mild_demented_images= os.listdir(image_directory + 'MildDemented/')
#      23 for i , image_name in enumerate(Mild_demented_images):
#      25     image = cv2.imread(image_directory+'MildDemented/'+image_name)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\code\\hair_diseases\\traning\\hairdata+MildDemented/'
